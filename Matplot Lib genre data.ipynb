# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import config
import mysql.connector
import sqlite3 
config.host
# Out:
# 'flatiron.clnl5ba3xlkw.us-east-2.rds.amazonaws.com'

# %%
import pandas as pd
genre_data = pd.read_csv('genredata.csv')

c = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-77c481aef145> in <module>
#       2 genre_data = pd.read_csv('genredata.csv')
#       3
# ----> 4 c = conn.cursor()
#
# NameError: name 'conn' is not defined

# %%
genre_data
# Out:
#       id  year  films_released  market_share       gross  tickets_sold  \
# 0      1  1995              29        0.1452   771507571     177358047
# 1      2  1996              34        0.2229  1290490033     291966054
# 2      3  1997              23        0.1387   881902843     192135684
# 3      4  1998              29        0.2384  1614467732     344236174
# 4      5  1999              27        0.2197  1612432107     317407880
# 5      6  2000              30        0.1762  1327311892     246254507
# 6      7  2001              32        0.2715  2147483647     400860557
# 7      8  2002              45        0.3079  2147483647     485184060
# 8      9  2003              46        0.2637  2147483647     402011823
# 9     10  2004              47        0.3109  2147483647     465029564
# 10    11  2005              43        0.2887  2147483647     396437158
# 11    12  2006              44        0.2995  2147483647     418886249
# 12    13  2007              41        0.2983  2147483647     423660835
# 13    14  2008              57        0.3085  2147483647     418894996
# 14    15  2009              49        0.2649  2147483647     375827476
# 15    16  2010              44        0.3056  2147483647     405950482
# 16    17  2011              51        0.2728  2147483647     350025489
# 17    18  2012              48        0.2987  2147483647     412599414
# 18    19  2013              40        0.2664  2147483647     356749803
# 19    20  2014              49        0.2662  2147483647     334756601
# 20    21  2015              51        0.2747  2147483647     363440937
# 21    22  2016              53        0.3694  2147483647     480825172
# 22    23  2017              44        0.2445  2147483647     299653307
# 23    24  2018              50        0.2464  2147483647     323532944
# 24    25  2019              29        0.3141  2098270756     230326086
# 25    26  1995              29        0.1975  1049544278     241274531
# 26    27  1996              36        0.2112  1222675745     276623456
# 27    28  1997              36        0.2291  1456612580     317344773
# 28    29  1998              30        0.1437   973161753     207497162
# 29    30  1999              25        0.1240   910203960     179173997
# ..   ...   ...             ...           ...         ...           ...
# 283  284  2011               6        0.0094    95445317      12035978
# 284  285  2012               4        0.0026    28347099       3561192
# 285  286  2013               4        0.0060    64881892       7980550
# 286  287  2014               3        0.0003     3148116        385326
# 287  288  2015               1        0.0001     1150000        136417
# 288  289  2016               4        0.0024    27211033       3145782
# 289  290  2017               3        0.0003     2984320        332699
# 290  291  2019               5        0.0003     1758562        193034
# 291  292  2000               1        0.0000      332235         61639
# 292  293  2001               1        0.0000        2010           355
# 293  294  2002               1        0.0000      391835         67441
# 294  295  2003               2        0.0001      498239         82626
# 295  296  2004               3        0.0000      142093         22880
# 296  297  2006               3        0.0001      748135        114218
# 297  298  2007               2        0.0000      335887         48819
# 298  299  2008               1        0.0001      508695         70848
# 299  300  2009               1        0.0001      644635         85951
# 300  301  2010               3        0.0001     1173911        148783
# 301  302  2011               4        0.0001     1510823        190518
# 302  303  2012               2        0.0002     1900200        238718
# 303  304  2013               1        0.0002     2142342        263510
# 304  305  2014               2        0.0005     5136187        628663
# 305  306  2015               1        0.0002     2412493        286179
# 306  307  2016               4        0.0003     2862219        330890
# 307  308  2017               5        0.0004     4614134        514394
# 308  309  2018               3        0.0004     4787450        525514
# 309  310  2019               2        0.0005     3545060        389139
# 310  311  2014               1        0.0000       16826          2059
# 311  312  2015               3        0.0001      604870         71751
# 312  313  2018               1        0.0000        3267           359
#
#      inflation_adjusted_gross                   genre
# 0                  1615731808               Adventure
# 1                  2147483647               Adventure
# 2                  1750356081               Adventure
# 3                  2147483647               Adventure
# 4                  2147483647               Adventure
# 5                  2147483647               Adventure
# 6                  2147483647               Adventure
# 7                  2147483647               Adventure
# 8                  2147483647               Adventure
# 9                  2147483647               Adventure
# 10                 2147483647               Adventure
# 11                 2147483647               Adventure
# 12                 2147483647               Adventure
# 13                 2147483647               Adventure
# 14                 2147483647               Adventure
# 15                 2147483647               Adventure
# 16                 2147483647               Adventure
# 17                 2147483647               Adventure
# 18                 2147483647               Adventure
# 19                 2147483647               Adventure
# 20                 2147483647               Adventure
# 21                 2147483647               Adventure
# 22                 2147483647               Adventure
# 23                 2147483647               Adventure
# 24                 2098270643               Adventure
# 25                 2147483647                  Action
# 26                 2147483647                  Action
# 27                 2147483647                  Action
# 28                 1890299146                  Action
# 29                 1632275113                  Action
# ..                        ...                     ...
# 283                 109647760  Concert-or-Performance
# 284                  32442459  Concert-or-Performance
# 285                  72702811  Concert-or-Performance
# 286                   3510320  Concert-or-Performance
# 287                   1242759  Concert-or-Performance
# 288                  28658074  Concert-or-Performance
# 289                   3030888  Concert-or-Performance
# 290                   1758540  Concert-or-Performance
# 291                    561531         Multiple-Genres
# 292                      3234         Multiple-Genres
# 293                    614388         Multiple-Genres
# 294                    752723         Multiple-Genres
# 295                    208437         Multiple-Genres
# 296                   1040526         Multiple-Genres
# 297                    444741         Multiple-Genres
# 298                    645425         Multiple-Genres
# 299                    783014         Multiple-Genres
# 300                   1355413         Multiple-Genres
# 301                   1735619         Multiple-Genres
# 302                   2174721         Multiple-Genres
# 303                   2400576         Multiple-Genres
# 304                   5727120         Multiple-Genres
# 305                   2607091         Multiple-Genres
# 306                   3014408         Multiple-Genres
# 307                   4686129         Multiple-Genres
# 308                   4787433         Multiple-Genres
# 309                   3545056         Multiple-Genres
# 310                     18757                 Reality
# 311                    653652                 Reality
# 312                      3270                 Reality
#
# [313 rows x 8 columns]

# %%
# !pip install pandasql
from pandasql import sqldf
movie = lambda q: sqldf(q, globals())
# Out:
# Requirement already satisfied: pandasql in /anaconda3/lib/python3.7/site-packages (0.7.3)
# Requirement already satisfied: numpy in /anaconda3/lib/python3.7/site-packages (from pandasql) (1.16.2)
# Requirement already satisfied: sqlalchemy in /anaconda3/lib/python3.7/site-packages (from pandasql) (1.3.1)
# Requirement already satisfied: pandas in /anaconda3/lib/python3.7/site-packages (from pandasql) (0.24.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in /anaconda3/lib/python3.7/site-packages (from pandas->pandasql) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /anaconda3/lib/python3.7/site-packages (from pandas->pandasql) (2018.9)
# Requirement already satisfied: six>=1.5 in /anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas->pandasql) (1.12.0)

# %%
q2 = "select market_share from genre_data where genre = 'Action'"
q3 = "select market_share from genre_data where genre = 'Adventure'"
q4 = "select market_share from genre_data where genre = 'Drama'"
q5 = "select market_share from genre_data where genre = 'Comedy'"
q6 = "select market_share from genre_data where genre = 'Thriller-or-Suspense'"
q7 = "select market_share from genre_data where genre = 'Horror'"
q8 = "select market_share from genre_data where genre = 'Romantic-Comedy'"
q9 = "select market_share from genre_data where genre = 'Musical'"
q10 = "select market_share from genre_data where genre = 'Documentary'"
q11 = "select market_share from genre_data where genre = 'Black-Comedy'"
q12 = "select market_share from genre_data where genre = 'Western'"

q14 = "select market_share from genre_data where genre = 'Concert-or-Performance'"
q15 = "select market_share from genre_data where genre = 'Multiple-Genres'"
q16 = "select market_share from genre_data where genre = 'Reality'"
q17 = 'select year from genre_data where genre = "Action"'

years=movie(q17)
years_list = list(years['year'])
years_list
#set lambda functions
# Out:
# [1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019]

# %%
action_market = []
adventure_market = []
drama_market = []
comedy_market = []
thriller_market = []
horror_market = []
romantic_market = []
musical_market = []
documentary_market = []
black_comedy_market = []
western_market = []
concert_market = []
multiple_market = []
reality_market = []

#open up lists

action_market=list(movie(q2)['market_share'])
adventure_market=list(movie(q3)['market_share'])
drama_market=list(movie(q4)['market_share'])
comedy_market=list(movie(q5)['market_share'])
thriller_market=list(movie(q6)['market_share'])
horror_market=list(movie(q7)['market_share'])
romantic_market=list(movie(q8)['market_share'])
musical_market=list(movie(q9)['market_share'])
documentary_market=list(movie(q10)['market_share'])
black_comedy_market=list(movie(q11)['market_share'])
western_market=list(movie(q12)['market_share'])
concert_market=list(movie(q14)['market_share'])
multiple_market=list(movie(q15)['market_share'])
reality_market=list(movie(q16)['market_share'])

#populate lists with "market share" value from lambda'ed dataframe.

# %%
musical_market.insert(0,0)
western_market.insert(2,0)
western_market.insert(3,0)
western_market.insert(7,0)

# %%
action_market=movie(q2)

# %%
# action_list = list(action_market['market_share'])
#testing separation of values from df
romantic_market
# Out:
# [0.0559,
#  0.0738,
#  0.0467,
#  0.074,
#  0.0985,
#  0.0497,
#  0.0633,
#  0.0628,
#  0.0539,
#  0.0702,
#  0.05,
#  0.0374,
#  0.0751,
#  0.0339,
#  0.0604,
#  0.0494,
#  0.0568,
#  0.0309,
#  0.0181,
#  0.0258,
#  0.0066,
#  0.0122,
#  0.0078,
#  0.0202,
#  0.0122]

# %%
x = years_list
fig, axs = plt.subplots(3, 4, figsize=(30,15))

axs[0, 0].plot(x, action_market, color='darkgreen')
axs[0, 0].set_title('Action Market Share')
axs[0, 1].plot(x, adventure_market, color='orange')
axs[0, 1].set_title('Adventure Market Share')
axs[1, 0].plot(x, drama_market, color='green')
axs[1, 0].set_title('Drama Market Share')
axs[1, 1].plot(x, comedy_market, color='red')
axs[1, 1].set_title('Comedy Market Share]')
axs[0, 2].plot(x, thriller_market, color='blue')
axs[0, 2].set_title('Thriller Market Share')
axs[1, 2].plot(x, horror_market, color='purple')
axs[1, 2].set_title('Horror Market Share')
axs[2, 1].plot(x, romantic_market, color='magenta')
axs[2, 1].set_title('Romantic Comedy Market Share')
axs[2, 0].plot(x, musical_market, color='black')
axs[2, 0].set_title('Musical Market Share')
axs[2, 2].plot(x, documentary_market, color='salmon')
axs[2, 2].set_title('Documentary Market Share')
axs[0, 3].plot(x, black_comedy_market, color='indigo')
axs[0, 3].set_title('Black Comedy Market')
axs[1, 3].plot(x, western_market, color='brown')
axs[1, 3].set_title('Westerns Market')

for ax in axs.flat:
    ax.set(xlabel='Years', ylabel='Percent Market Share')

# Hide x labels and tick labels for top plots and y ticks for right plots.
# for ax in axs.flat:
#     ax.label_outer()

# %%
plt.figure(figsize=(20,10))

x = years_list
y_1 = action_market
y_2 = adventure_market
y_3 = thriller_market
y_4 = black_comedy_market
y_5 = drama_market
y_6 = comedy_market
y_7 = horror_market
y_8 = western_market
y_9 = musical_market
y_10 = romantic_market
y_11 = documentary_market

plt.plot(x, y_1)
plt.plot(x, y_2)
plt.plot(x, y_3)
plt.plot(x, y_4)
plt.plot(x, y_5)
plt.plot(x, y_6)
plt.plot(x, y_7)
plt.plot(x, y_8)
plt.plot(x, y_9)
plt.plot(x, y_10)
plt.plot(x, y_11)
plt.show()
